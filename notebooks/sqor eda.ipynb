# %%
import sys;sys.path.append("..")
import pandas as pd
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from devml import (mkdata, stats, state, fetch_repo, ts)

# %%
df = mkdata.create_org_df(path="/Users/noahgift/src/sqor")
# Out:
# 2018-02-06 14:07:19,205 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/riemann
# 2018-02-06 14:07:19,207 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/riemann
# 2018-02-06 14:07:19,230 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:noahgift/devml.git (fetch)\norigin\tgit@github.com:noahgift/devml.git (push)\n'
# 2018-02-06 14:07:19,259 - devml.mkdata - INFO - Repo Name: b'riemann'
# 2018-02-06 14:07:19,321 - devml.mkdata - INFO - Found 966 Messages For Repo: b'riemann'
# 2018-02-06 14:07:19,325 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/haproxy-patches
# 2018-02-06 14:07:19,326 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/haproxy-patches
# 2018-02-06 14:07:19,345 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:aphyr/riemann.git (fetch)\norigin\tgit@github.com:aphyr/riemann.git (push)\n'
# 2018-02-06 14:07:19,369 - devml.mkdata - INFO - Repo Name: b'haproxy-patches'
# 2018-02-06 14:07:19,411 - devml.mkdata - INFO - Found 19 Messages For Repo: b'haproxy-patches'
# 2018-02-06 14:07:19,414 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sqor_sockets
# 2018-02-06 14:07:19,414 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sqor_sockets
# 2018-02-06 14:07:19,430 - devml.mkdata - INFO - guid: b'origin\thttps://github.com/cbonte/haproxy-patches.git (fetch)\norigin\thttps://github.com/cbonte/haproxy-patches.git (push)\n'
# 2018-02-06 14:07:19,457 - devml.mkdata - INFO - Repo Name: b'sqor_sockets'
# 2018-02-06 14:07:19,483 - devml.mkdata - INFO - Found 46 Messages For Repo: b'sqor_sockets'
# 2018-02-06 14:07:19,487 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/data_collect
# 2018-02-06 14:07:19,489 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/data_collect
# 2018-02-06 14:07:19,511 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sqor_sockets.git (fetch)\norigin\tgit@github.com:Amplify-Social/sqor_sockets.git (push)\n'
# 2018-02-06 14:07:19,541 - devml.mkdata - INFO - Repo Name: b'data_collect'
# 2018-02-06 14:07:19,568 - devml.mkdata - INFO - Found 36 Messages For Repo: b'data_collect'
# 2018-02-06 14:07:19,571 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/documentation
# 2018-02-06 14:07:19,573 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/documentation
# 2018-02-06 14:07:19,594 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/data_collect.git (fetch)\norigin\tgit@github.com:Amplify-Social/data_collect.git (push)\n'
# 2018-02-06 14:07:19,623 - devml.mkdata - INFO - Repo Name: b'documentation'
# 2018-02-06 14:07:19,655 - devml.mkdata - INFO - Found 17 Messages For Repo: b'documentation'
# 2018-02-06 14:07:19,657 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/erlang_app_template
# 2018-02-06 14:07:19,659 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/erlang_app_template
# 2018-02-06 14:07:19,676 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/documentation.git (fetch)\norigin\tgit@github.com:Amplify-Social/documentation.git (push)\n'
# 2018-02-06 14:07:19,700 - devml.mkdata - INFO - Repo Name: b'erlang_app_template'
# 2018-02-06 14:07:19,721 - devml.mkdata - INFO - Found 5 Messages For Repo: b'erlang_app_template'
# 2018-02-06 14:07:19,724 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/gitinspector
# 2018-02-06 14:07:19,725 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/gitinspector
# 2018-02-06 14:07:19,741 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/erlang_app_template.git (fetch)\norigin\tgit@github.com:Amplify-Social/erlang_app_template.git (push)\n'
# 2018-02-06 14:07:19,766 - devml.mkdata - INFO - Repo Name: b'gitinspector'
# 2018-02-06 14:07:19,799 - devml.mkdata - INFO - Found 313 Messages For Repo: b'gitinspector'
# 2018-02-06 14:07:19,802 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/erlang-deploy
# 2018-02-06 14:07:19,803 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/erlang-deploy
# 2018-02-06 14:07:19,829 - devml.mkdata - INFO - guid: b'origin\thttps://code.google.com/p/gitinspector/ (fetch)\norigin\thttps://code.google.com/p/gitinspector/ (push)\n'
# 2018-02-06 14:07:19,849 - devml.mkdata - INFO - Repo Name: b'erlang-deploy'
# 2018-02-06 14:07:19,872 - devml.mkdata - INFO - Found 1 Messages For Repo: b'erlang-deploy'
# 2018-02-06 14:07:19,876 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/test_output
# 2018-02-06 14:07:19,878 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/test_output
# 2018-02-06 14:07:19,897 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/erlang-deploy.git (fetch)\norigin\tgit@github.com:Amplify-Social/erlang-deploy.git (push)\n'
# 2018-02-06 14:07:19,925 - devml.mkdata - INFO - Repo Name: b'test_output'
# 2018-02-06 14:07:20,052 - devml.mkdata - INFO - Found 367 Messages For Repo: b'test_output'
# 2018-02-06 14:07:20,055 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/ecommerce
# 2018-02-06 14:07:20,056 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/ecommerce
# 2018-02-06 14:07:20,076 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/web.git (fetch)\norigin\tgit@github.com:Amplify-Social/web.git (push)\n'
# 2018-02-06 14:07:20,104 - devml.mkdata - INFO - Repo Name: b'ecommerce'
# 2018-02-06 14:07:20,136 - devml.mkdata - INFO - Found 3 Messages For Repo: b'ecommerce'
# 2018-02-06 14:07:20,140 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/dbinterface
# 2018-02-06 14:07:20,142 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/dbinterface
# 2018-02-06 14:07:20,159 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/ecommerce.git (fetch)\norigin\tgit@github.com:Amplify-Social/ecommerce.git (push)\n'
# 2018-02-06 14:07:20,187 - devml.mkdata - INFO - Repo Name: b'dbinterface'
# 2018-02-06 14:07:20,248 - devml.mkdata - INFO - Found 303 Messages For Repo: b'dbinterface'
# 2018-02-06 14:07:20,252 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/util
# 2018-02-06 14:07:20,253 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/util
# 2018-02-06 14:07:20,275 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/dbinterface.git (fetch)\norigin\tgit@github.com:Amplify-Social/dbinterface.git (push)\n'
# 2018-02-06 14:07:20,309 - devml.mkdata - INFO - Repo Name: b'util'
# 2018-02-06 14:07:20,406 - devml.mkdata - INFO - Found 536 Messages For Repo: b'util'
# 2018-02-06 14:07:20,409 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/echart
# 2018-02-06 14:07:20,410 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/echart
# 2018-02-06 14:07:20,431 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/util.git (fetch)\norigin\tgit@github.com:Amplify-Social/util.git (push)\n'
# 2018-02-06 14:07:20,460 - devml.mkdata - INFO - Repo Name: b'echart'
# 2018-02-06 14:07:20,487 - devml.mkdata - INFO - Found 1 Messages For Repo: b'echart'
# 2018-02-06 14:07:20,490 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sqor_stats_rest
# 2018-02-06 14:07:20,491 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sqor_stats_rest
# 2018-02-06 14:07:20,512 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/echart.git (fetch)\norigin\tgit@github.com:Amplify-Social/echart.git (push)\n'
# 2018-02-06 14:07:20,547 - devml.mkdata - INFO - Repo Name: b'sqor_stats_rest'
# 2018-02-06 14:07:20,573 - devml.mkdata - INFO - Found 51 Messages For Repo: b'sqor_stats_rest'
# 2018-02-06 14:07:20,576 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/scripty_cluster
# 2018-02-06 14:07:20,577 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/scripty_cluster
# 2018-02-06 14:07:20,595 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sqor_stats_rest.git (fetch)\norigin\tgit@github.com:Amplify-Social/sqor_stats_rest.git (push)\n'
# 2018-02-06 14:07:20,622 - devml.mkdata - INFO - Repo Name: b'scripty_cluster'
# 2018-02-06 14:07:20,647 - devml.mkdata - INFO - Found 25 Messages For Repo: b'scripty_cluster'
# 2018-02-06 14:07:20,649 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/entry
# 2018-02-06 14:07:20,650 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/entry
# 2018-02-06 14:07:20,667 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/scripty_cluster.git (fetch)\norigin\tgit@github.com:Amplify-Social/scripty_cluster.git (push)\n'
# 2018-02-06 14:07:20,690 - devml.mkdata - INFO - Repo Name: b''
# 2018-02-06 14:07:20,711 - devml.mkdata - INFO - Found 1 Messages For Repo: b''
# 2018-02-06 14:07:20,716 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/SqorUtils
# 2018-02-06 14:07:20,717 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/SqorUtils
# 2018-02-06 14:07:20,735 - devml.mkdata - INFO - guid: b''
# 2018-02-06 14:07:20,758 - devml.mkdata - INFO - Repo Name: b'SqorUtils'
# 2018-02-06 14:07:20,779 - devml.mkdata - INFO - Found 2 Messages For Repo: b'SqorUtils'
# 2018-02-06 14:07:20,781 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/_web_report
# 2018-02-06 14:07:20,782 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/_web_report
# 2018-02-06 14:07:20,802 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/SqorUtils.git (fetch)\norigin\tgit@github.com:Amplify-Social/SqorUtils.git (push)\n'
# 2018-02-06 14:07:20,824 - devml.mkdata - INFO - Repo Name: b''
# 2018-02-06 14:07:20,840 - devml.mkdata - INFO - Found 1 Messages For Repo: b''
# 2018-02-06 14:07:20,843 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/web
# 2018-02-06 14:07:20,844 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/web
# 2018-02-06 14:07:20,862 - devml.mkdata - INFO - guid: b''
# 2018-02-06 14:07:20,890 - devml.mkdata - INFO - Repo Name: b'web'
# 2018-02-06 14:07:21,111 - devml.mkdata - INFO - Found 6400 Messages For Repo: b'web'
# 2018-02-06 14:07:21,116 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/fightmetric
# 2018-02-06 14:07:21,117 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/fightmetric
# 2018-02-06 14:07:21,133 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/web.git (fetch)\norigin\tgit@github.com:Amplify-Social/web.git (push)\n'
# 2018-02-06 14:07:21,157 - devml.mkdata - INFO - Repo Name: b'fightmetric'
# 2018-02-06 14:07:21,184 - devml.mkdata - INFO - Found 1 Messages For Repo: b'fightmetric'
# 2018-02-06 14:07:21,189 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sqor_scheduler
# 2018-02-06 14:07:21,190 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sqor_scheduler
# 2018-02-06 14:07:21,209 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/fightmetric.git (fetch)\norigin\tgit@github.com:Amplify-Social/fightmetric.git (push)\n'
# 2018-02-06 14:07:21,240 - devml.mkdata - INFO - Repo Name: b'sqor_scheduler'
# 2018-02-06 14:07:21,270 - devml.mkdata - INFO - Found 138 Messages For Repo: b'sqor_scheduler'
# 2018-02-06 14:07:21,273 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/learning_python
# 2018-02-06 14:07:21,274 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/learning_python
# 2018-02-06 14:07:21,294 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sqor_scheduler.git (fetch)\norigin\tgit@github.com:Amplify-Social/sqor_scheduler.git (push)\n'
# 2018-02-06 14:07:21,320 - devml.mkdata - INFO - Repo Name: b'learning_python'
# 2018-02-06 14:07:21,344 - devml.mkdata - INFO - Found 1 Messages For Repo: b'learning_python'
# 2018-02-06 14:07:21,347 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/ricardo
# 2018-02-06 14:07:21,348 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/ricardo
# 2018-02-06 14:07:21,367 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/learning_python.git (fetch)\norigin\tgit@github.com:Amplify-Social/learning_python.git (push)\n'
# 2018-02-06 14:07:21,394 - devml.mkdata - INFO - Repo Name: b'ricardo'
# 2018-02-06 14:07:21,419 - devml.mkdata - INFO - Found 25 Messages For Repo: b'ricardo'
# 2018-02-06 14:07:21,423 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sqor_message_producer
# 2018-02-06 14:07:21,424 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sqor_message_producer
# 2018-02-06 14:07:21,446 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/ricardo.git (fetch)\norigin\tgit@github.com:Amplify-Social/ricardo.git (push)\n'
# 2018-02-06 14:07:21,472 - devml.mkdata - INFO - Repo Name: b'sqor_message_producer'
# 2018-02-06 14:07:21,502 - devml.mkdata - INFO - Found 8 Messages For Repo: b'sqor_message_producer'
# 2018-02-06 14:07:21,505 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/data_science_pipeline
# 2018-02-06 14:07:21,505 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/data_science_pipeline
# 2018-02-06 14:07:21,525 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sqor_message_producer.git (fetch)\norigin\tgit@github.com:Amplify-Social/sqor_message_producer.git (push)\n'
# 2018-02-06 14:07:21,552 - devml.mkdata - INFO - Repo Name: b'data_science_pipeline'
# 2018-02-06 14:07:21,578 - devml.mkdata - INFO - Found 3 Messages For Repo: b'data_science_pipeline'
# 2018-02-06 14:07:21,581 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/node_modules
# 2018-02-06 14:07:21,581 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/node_modules
# 2018-02-06 14:07:21,600 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/data_science_pipeline.git (fetch)\norigin\tgit@github.com:Amplify-Social/data_science_pipeline.git (push)\n'
# 2018-02-06 14:07:21,627 - devml.mkdata - INFO - Repo Name: b''
# 2018-02-06 14:07:21,646 - devml.mkdata - INFO - Found 1 Messages For Repo: b''
# 2018-02-06 14:07:21,648 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sqor_algo
# 2018-02-06 14:07:21,649 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sqor_algo
# 2018-02-06 14:07:21,668 - devml.mkdata - INFO - guid: b''
# 2018-02-06 14:07:21,699 - devml.mkdata - INFO - Repo Name: b'sqor_algo'
# 2018-02-06 14:07:21,728 - devml.mkdata - INFO - Found 73 Messages For Repo: b'sqor_algo'
# 2018-02-06 14:07:21,731 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/asset_pipeline
# 2018-02-06 14:07:21,732 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/asset_pipeline
# 2018-02-06 14:07:21,750 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sqor_algo.git (fetch)\norigin\tgit@github.com:Amplify-Social/sqor_algo.git (push)\n'
# 2018-02-06 14:07:21,778 - devml.mkdata - INFO - Repo Name: b'asset_pipeline'
# 2018-02-06 14:07:21,829 - devml.mkdata - INFO - Found 90 Messages For Repo: b'asset_pipeline'
# 2018-02-06 14:07:21,832 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/SQ2_Docker_App
# 2018-02-06 14:07:21,833 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/SQ2_Docker_App
# 2018-02-06 14:07:21,847 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/asset_pipeline.git (fetch)\norigin\tgit@github.com:Amplify-Social/asset_pipeline.git (push)\n'
# 2018-02-06 14:07:21,868 - devml.mkdata - INFO - Repo Name: b'SQ2_Docker_App'
# 2018-02-06 14:07:21,889 - devml.mkdata - INFO - Found 2 Messages For Repo: b'SQ2_Docker_App'
# 2018-02-06 14:07:21,891 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/Football2.0
# 2018-02-06 14:07:21,891 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/Football2.0
# 2018-02-06 14:07:21,905 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/SQ2_Docker_App.git (fetch)\norigin\tgit@github.com:Amplify-Social/SQ2_Docker_App.git (push)\n'
# 2018-02-06 14:07:21,925 - devml.mkdata - INFO - Repo Name: b'Football2.0'
# 2018-02-06 14:07:21,952 - devml.mkdata - INFO - Found 116 Messages For Repo: b'Football2.0'
# 2018-02-06 14:07:21,956 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/opsworks_sqor_cookbook-noah
# 2018-02-06 14:07:21,956 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/opsworks_sqor_cookbook-noah
# 2018-02-06 14:07:21,976 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/Football2.0.git (fetch)\norigin\tgit@github.com:Amplify-Social/Football2.0.git (push)\n'
# 2018-02-06 14:07:22,005 - devml.mkdata - INFO - Repo Name: b'opsworks_sqor_cookbook-noah'
# 2018-02-06 14:07:22,036 - devml.mkdata - INFO - Found 121 Messages For Repo: b'opsworks_sqor_cookbook-noah'
# 2018-02-06 14:07:22,038 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sports_stats
# 2018-02-06 14:07:22,039 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sports_stats
# 2018-02-06 14:07:22,053 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:noahgift/opsworks_sqor_cookbook.git (fetch)\norigin\tgit@github.com:noahgift/opsworks_sqor_cookbook.git (push)\n'
# 2018-02-06 14:07:22,074 - devml.mkdata - INFO - Repo Name: b'sports_stats'
# 2018-02-06 14:07:22,099 - devml.mkdata - INFO - Found 15 Messages For Repo: b'sports_stats'
# 2018-02-06 14:07:22,101 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/hubbard
# 2018-02-06 14:07:22,102 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/hubbard
# 2018-02-06 14:07:22,118 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sports_stats.git (fetch)\norigin\tgit@github.com:Amplify-Social/sports_stats.git (push)\n'
# 2018-02-06 14:07:22,140 - devml.mkdata - INFO - Repo Name: b'hubbard'
# 2018-02-06 14:07:22,172 - devml.mkdata - INFO - Found 65 Messages For Repo: b'hubbard'
# 2018-02-06 14:07:22,174 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/athlete_prediction
# 2018-02-06 14:07:22,175 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/athlete_prediction
# 2018-02-06 14:07:22,190 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/hubbard.git (fetch)\norigin\tgit@github.com:Amplify-Social/hubbard.git (push)\n'
# 2018-02-06 14:07:22,211 - devml.mkdata - INFO - Repo Name: b'athlete_prediction'
# 2018-02-06 14:07:22,231 - devml.mkdata - INFO - Found 1 Messages For Repo: b'athlete_prediction'
# 2018-02-06 14:07:22,234 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/eweb
# 2018-02-06 14:07:22,235 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/eweb
# 2018-02-06 14:07:22,249 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/athlete_prediction.git (fetch)\norigin\tgit@github.com:Amplify-Social/athlete_prediction.git (push)\n'
# 2018-02-06 14:07:22,270 - devml.mkdata - INFO - Repo Name: b'eweb'
# 2018-02-06 14:07:22,339 - devml.mkdata - INFO - Found 128 Messages For Repo: b'eweb'
# 2018-02-06 14:07:22,343 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/loadtest
# 2018-02-06 14:07:22,343 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/loadtest
# 2018-02-06 14:07:22,359 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/eweb.git (fetch)\norigin\tgit@github.com:Amplify-Social/eweb.git (push)\n'
# 2018-02-06 14:07:22,379 - devml.mkdata - INFO - Repo Name: b'loadtest'
# 2018-02-06 14:07:22,399 - devml.mkdata - INFO - Found 3 Messages For Repo: b'loadtest'
# 2018-02-06 14:07:22,402 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/SQ2_AppUmbrella
# 2018-02-06 14:07:22,403 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/SQ2_AppUmbrella
# 2018-02-06 14:07:22,422 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/loadtest.git (fetch)\norigin\tgit@github.com:Amplify-Social/loadtest.git (push)\n'
# 2018-02-06 14:07:22,451 - devml.mkdata - INFO - Repo Name: b'SQ2_AppUmbrella'
# 2018-02-06 14:07:22,478 - devml.mkdata - INFO - Found 8 Messages For Repo: b'SQ2_AppUmbrella'
# 2018-02-06 14:07:22,482 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/eidolon
# 2018-02-06 14:07:22,483 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/eidolon
# 2018-02-06 14:07:22,502 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/SQ2_AppUmbrella.git (fetch)\norigin\tgit@github.com:Amplify-Social/SQ2_AppUmbrella.git (push)\n'
# 2018-02-06 14:07:22,524 - devml.mkdata - INFO - Repo Name: b'eidolon'
# 2018-02-06 14:07:22,567 - devml.mkdata - INFO - Found 493 Messages For Repo: b'eidolon'
# 2018-02-06 14:07:22,570 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sail
# 2018-02-06 14:07:22,571 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sail
# 2018-02-06 14:07:22,587 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:artsy/eidolon.git (fetch)\norigin\tgit@github.com:artsy/eidolon.git (push)\n'
# 2018-02-06 14:07:22,608 - devml.mkdata - INFO - Repo Name: b'sail'
# 2018-02-06 14:07:22,630 - devml.mkdata - INFO - Found 32 Messages For Repo: b'sail'
# 2018-02-06 14:07:22,633 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/opsworks_sqor_cookbook
# 2018-02-06 14:07:22,634 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/opsworks_sqor_cookbook
# 2018-02-06 14:07:22,652 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:jasoncbautista/sail.git (fetch)\norigin\tgit@github.com:jasoncbautista/sail.git (push)\n'
# 2018-02-06 14:07:22,677 - devml.mkdata - INFO - Repo Name: b'opsworks_sqor_cookbook'
# 2018-02-06 14:07:22,766 - devml.mkdata - INFO - Found 1020 Messages For Repo: b'opsworks_sqor_cookbook'
# 2018-02-06 14:07:22,769 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/lesson3_notes
# 2018-02-06 14:07:22,770 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/lesson3_notes
# 2018-02-06 14:07:22,787 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/opsworks_sqor_cookbook.git (fetch)\norigin\tgit@github.com:Amplify-Social/opsworks_sqor_cookbook.git (push)\n'
# 2018-02-06 14:07:22,810 - devml.mkdata - INFO - Repo Name: b''
# 2018-02-06 14:07:22,836 - devml.mkdata - INFO - Found 1 Messages For Repo: b''
# 2018-02-06 14:07:22,839 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/links
# 2018-02-06 14:07:22,840 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/links
# 2018-02-06 14:07:22,859 - devml.mkdata - INFO - guid: b''
# 2018-02-06 14:07:22,885 - devml.mkdata - INFO - Repo Name: b'links'
# 2018-02-06 14:07:22,925 - devml.mkdata - INFO - Found 34 Messages For Repo: b'links'
# 2018-02-06 14:07:22,927 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sqor_web
# 2018-02-06 14:07:22,928 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sqor_web
# 2018-02-06 14:07:22,942 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/links.git (fetch)\norigin\tgit@github.com:Amplify-Social/links.git (push)\n'
# 2018-02-06 14:07:22,967 - devml.mkdata - INFO - Repo Name: b'sqor_web'
# 2018-02-06 14:07:23,001 - devml.mkdata - INFO - Found 337 Messages For Repo: b'sqor_web'
# 2018-02-06 14:07:23,003 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/business_forecasting
# 2018-02-06 14:07:23,004 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/business_forecasting
# 2018-02-06 14:07:23,018 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sqor_web.git (fetch)\norigin\tgit@github.com:Amplify-Social/sqor_web.git (push)\n'
# 2018-02-06 14:07:23,040 - devml.mkdata - INFO - Repo Name: b'business_forecasting'
# 2018-02-06 14:07:23,351 - devml.mkdata - INFO - Found 861 Messages For Repo: b'business_forecasting'
# 2018-02-06 14:07:23,353 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/_sqor_report
# 2018-02-06 14:07:23,354 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/_sqor_report
# 2018-02-06 14:07:23,371 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/business_forecasting.git (fetch)\norigin\tgit@github.com:Amplify-Social/business_forecasting.git (push)\n'
# 2018-02-06 14:07:23,395 - devml.mkdata - INFO - Repo Name: b''
# 2018-02-06 14:07:23,413 - devml.mkdata - INFO - Found 1 Messages For Repo: b''
# 2018-02-06 14:07:23,416 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/emeter
# 2018-02-06 14:07:23,416 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/emeter
# 2018-02-06 14:07:23,432 - devml.mkdata - INFO - guid: b''
# 2018-02-06 14:07:23,456 - devml.mkdata - INFO - Repo Name: b'emeter'
# 2018-02-06 14:07:23,491 - devml.mkdata - INFO - Found 18 Messages For Repo: b'emeter'
# 2018-02-06 14:07:23,493 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sitemapper
# 2018-02-06 14:07:23,494 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sitemapper
# 2018-02-06 14:07:23,513 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/emeter.git (fetch)\norigin\tgit@github.com:Amplify-Social/emeter.git (push)\n'
# 2018-02-06 14:07:23,537 - devml.mkdata - INFO - Repo Name: b'sitemapper'
# 2018-02-06 14:07:23,562 - devml.mkdata - INFO - Found 15 Messages For Repo: b'sitemapper'
# 2018-02-06 14:07:23,564 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/httpie
# 2018-02-06 14:07:23,564 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/httpie
# 2018-02-06 14:07:23,580 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sitemapper.git (fetch)\norigin\tgit@github.com:Amplify-Social/sitemapper.git (push)\n'
# 2018-02-06 14:07:23,602 - devml.mkdata - INFO - Repo Name: b'httpie'
# 2018-02-06 14:07:23,640 - devml.mkdata - INFO - Found 508 Messages For Repo: b'httpie'
# 2018-02-06 14:07:23,643 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/fuser
# 2018-02-06 14:07:23,644 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/fuser
# 2018-02-06 14:07:23,660 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:jakubroztocil/httpie.git (fetch)\norigin\tgit@github.com:jakubroztocil/httpie.git (push)\n'
# 2018-02-06 14:07:23,683 - devml.mkdata - INFO - Repo Name: b'fuser'
# 2018-02-06 14:07:23,704 - devml.mkdata - INFO - Found 48 Messages For Repo: b'fuser'
# 2018-02-06 14:07:23,706 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/SqorRest
# 2018-02-06 14:07:23,707 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/SqorRest
# 2018-02-06 14:07:23,724 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/fuser.git (fetch)\norigin\tgit@github.com:Amplify-Social/fuser.git (push)\n'
# 2018-02-06 14:07:23,749 - devml.mkdata - INFO - Repo Name: b'SqorRest'
# 2018-02-06 14:07:23,850 - devml.mkdata - INFO - Found 2674 Messages For Repo: b'SqorRest'
# 2018-02-06 14:07:23,853 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/management_science
# 2018-02-06 14:07:23,854 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/management_science
# 2018-02-06 14:07:23,869 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/SqorRest.git (fetch)\norigin\tgit@github.com:Amplify-Social/SqorRest.git (push)\n'
# 2018-02-06 14:07:23,893 - devml.mkdata - INFO - Repo Name: b'management_science'
# 2018-02-06 14:07:23,918 - devml.mkdata - INFO - Found 2 Messages For Repo: b'management_science'
# 2018-02-06 14:07:23,921 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/feed_tools
# 2018-02-06 14:07:23,922 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/feed_tools
# 2018-02-06 14:07:23,941 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/management_science.git (fetch)\norigin\tgit@github.com:Amplify-Social/management_science.git (push)\n'
# 2018-02-06 14:07:23,973 - devml.mkdata - INFO - Repo Name: b'feed_tools'
# 2018-02-06 14:07:24,016 - devml.mkdata - INFO - Found 422 Messages For Repo: b'feed_tools'
# 2018-02-06 14:07:24,018 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/.pyenv
# 2018-02-06 14:07:24,019 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/.pyenv
# 2018-02-06 14:07:24,038 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/feed_tools.git (fetch)\norigin\tgit@github.com:Amplify-Social/feed_tools.git (push)\n'
# 2018-02-06 14:07:24,061 - devml.mkdata - INFO - Repo Name: b''
# 2018-02-06 14:07:24,080 - devml.mkdata - INFO - Found 1 Messages For Repo: b''
# 2018-02-06 14:07:24,084 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sqor_rest
# 2018-02-06 14:07:24,086 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sqor_rest
# 2018-02-06 14:07:24,105 - devml.mkdata - INFO - guid: b''
# 2018-02-06 14:07:24,134 - devml.mkdata - INFO - Repo Name: b'sqor_rest'
# 2018-02-06 14:07:24,175 - devml.mkdata - INFO - Found 270 Messages For Repo: b'sqor_rest'
# 2018-02-06 14:07:24,178 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/python-github3
# 2018-02-06 14:07:24,178 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/python-github3
# 2018-02-06 14:07:24,194 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sqor_rest.git (fetch)\norigin\tgit@github.com:Amplify-Social/sqor_rest.git (push)\n'
# 2018-02-06 14:07:24,215 - devml.mkdata - INFO - Repo Name: b'python-github3'
# 2018-02-06 14:07:24,246 - devml.mkdata - INFO - Found 338 Messages For Repo: b'python-github3'
# 2018-02-06 14:07:24,249 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/3rdeye
# 2018-02-06 14:07:24,249 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/3rdeye
# 2018-02-06 14:07:24,264 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:copitux/python-github3.git (fetch)\norigin\tgit@github.com:copitux/python-github3.git (push)\n'
# 2018-02-06 14:07:24,284 - devml.mkdata - INFO - Repo Name: b'3rdeye'
# 2018-02-06 14:07:24,307 - devml.mkdata - INFO - Found 44 Messages For Repo: b'3rdeye'
# 2018-02-06 14:07:24,310 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/seo
# 2018-02-06 14:07:24,310 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/seo
# 2018-02-06 14:07:24,324 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:sqor/3rdeye.git (fetch)\norigin\tgit@github.com:sqor/3rdeye.git (push)\n'
# 2018-02-06 14:07:24,344 - devml.mkdata - INFO - Repo Name: b'seo'
# 2018-02-06 14:07:24,365 - devml.mkdata - INFO - Found 1 Messages For Repo: b'seo'
# 2018-02-06 14:07:24,369 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/BrettFavreSwiftGame
# 2018-02-06 14:07:24,370 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/BrettFavreSwiftGame
# 2018-02-06 14:07:24,388 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/seo.git (fetch)\norigin\tgit@github.com:Amplify-Social/seo.git (push)\n'
# 2018-02-06 14:07:24,414 - devml.mkdata - INFO - Repo Name: b'BrettFavreSwiftGame'
# 2018-02-06 14:07:24,452 - devml.mkdata - INFO - Found 551 Messages For Repo: b'BrettFavreSwiftGame'
# 2018-02-06 14:07:24,454 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/rgithub
# 2018-02-06 14:07:24,455 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/rgithub
# 2018-02-06 14:07:24,469 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/BrettFavreSwiftGame.git (fetch)\norigin\tgit@github.com:Amplify-Social/BrettFavreSwiftGame.git (push)\n'
# 2018-02-06 14:07:24,489 - devml.mkdata - INFO - Repo Name: b'rgithub'
# 2018-02-06 14:07:24,513 - devml.mkdata - INFO - Found 115 Messages For Repo: b'rgithub'
# 2018-02-06 14:07:24,516 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/SqorMobileiOS
# 2018-02-06 14:07:24,517 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/SqorMobileiOS
# 2018-02-06 14:07:24,532 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:cscheid/rgithub.git (fetch)\norigin\tgit@github.com:cscheid/rgithub.git (push)\n'
# 2018-02-06 14:07:24,554 - devml.mkdata - INFO - Repo Name: b'SqorMobileiOS'
# 2018-02-06 14:07:24,620 - devml.mkdata - INFO - Found 1598 Messages For Repo: b'SqorMobileiOS'
# 2018-02-06 14:07:24,622 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sass_rest
# 2018-02-06 14:07:24,623 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sass_rest
# 2018-02-06 14:07:24,640 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/SqorMobileiOS.git (fetch)\norigin\tgit@github.com:Amplify-Social/SqorMobileiOS.git (push)\n'
# 2018-02-06 14:07:24,664 - devml.mkdata - INFO - Repo Name: b'sass_rest'
# 2018-02-06 14:07:24,686 - devml.mkdata - INFO - Found 2 Messages For Repo: b'sass_rest'
# 2018-02-06 14:07:24,689 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/saas_algo
# 2018-02-06 14:07:24,689 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/saas_algo
# 2018-02-06 14:07:24,705 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/sass_rest.git (fetch)\norigin\tgit@github.com:Amplify-Social/sass_rest.git (push)\n'
# 2018-02-06 14:07:24,727 - devml.mkdata - INFO - Repo Name: b'saas_algo'
# 2018-02-06 14:07:24,757 - devml.mkdata - INFO - Found 247 Messages For Repo: b'saas_algo'
# 2018-02-06 14:07:24,760 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/AzureML-Regression-Example
# 2018-02-06 14:07:24,761 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/AzureML-Regression-Example
# 2018-02-06 14:07:24,776 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/saas_algo.git (fetch)\norigin\tgit@github.com:Amplify-Social/saas_algo.git (push)\n'
# 2018-02-06 14:07:24,798 - devml.mkdata - INFO - Repo Name: b'AzureML-Regression-Example'
# 2018-02-06 14:07:24,825 - devml.mkdata - INFO - Found 13 Messages For Repo: b'AzureML-Regression-Example'
# 2018-02-06 14:07:24,828 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/gitstats
# 2018-02-06 14:07:24,829 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/gitstats
# 2018-02-06 14:07:24,849 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Quantia-Analytics/AzureML-Regression-Example.git (fetch)\norigin\tgit@github.com:Quantia-Analytics/AzureML-Regression-Example.git (push)\n'
# 2018-02-06 14:07:24,878 - devml.mkdata - INFO - Repo Name: b'gitstats'
# 2018-02-06 14:07:24,909 - devml.mkdata - INFO - Found 289 Messages For Repo: b'gitstats'
# 2018-02-06 14:07:24,911 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/runr
# 2018-02-06 14:07:24,912 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/runr
# 2018-02-06 14:07:24,928 - devml.mkdata - INFO - guid: b'origin\tgit://github.com/hoxu/gitstats.git (fetch)\norigin\tgit://github.com/hoxu/gitstats.git (push)\n'
# 2018-02-06 14:07:24,949 - devml.mkdata - INFO - Repo Name: b'runr'
# 2018-02-06 14:07:24,979 - devml.mkdata - INFO - Found 18 Messages For Repo: b'runr'
# 2018-02-06 14:07:24,981 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/dockerlang
# 2018-02-06 14:07:24,982 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/dockerlang
# 2018-02-06 14:07:24,998 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/runr.git (fetch)\norigin\tgit@github.com:Amplify-Social/runr.git (push)\n'
# 2018-02-06 14:07:25,018 - devml.mkdata - INFO - Repo Name: b'dockerlang'
# 2018-02-06 14:07:25,042 - devml.mkdata - INFO - Found 9 Messages For Repo: b'dockerlang'
# 2018-02-06 14:07:25,044 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/SqorMobile
# 2018-02-06 14:07:25,045 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/SqorMobile
# 2018-02-06 14:07:25,062 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/dockerlang.git (fetch)\norigin\tgit@github.com:Amplify-Social/dockerlang.git (push)\n'
# 2018-02-06 14:07:25,086 - devml.mkdata - INFO - Repo Name: b'SqorMobile'
# 2018-02-06 14:07:25,231 - devml.mkdata - INFO - Found 1688 Messages For Repo: b'SqorMobile'
# 2018-02-06 14:07:25,234 - devml.mkdata - INFO - Found repo: /Users/noahgift/src/sqor/sqor_ft_rest
# 2018-02-06 14:07:25,234 - devml.mkdata - INFO - Processing Repo: /Users/noahgift/src/sqor/sqor_ft_rest
# 2018-02-06 14:07:25,253 - devml.mkdata - INFO - guid: b'origin\tgit@github.com:Amplify-Social/SqorMobile.git (fetch)\norigin\tgit@github.com:Amplify-Social/SqorMobile.git (push)\n'
# 2018-02-06 14:07:25,274 - devml.mkdata - INFO - Repo Name: b'sqor_ft_rest'
# 2018-02-06 14:07:25,324 - devml.mkdata - INFO - Found 322 Messages For Repo: b'sqor_ft_rest'
# 2018-02-06 14:07:25,327 - devml.mkdata - INFO - Found a total log entries: 21864
# 2018-02-06 14:07:25,478 - devml.mkdata - INFO - Changing back to original cwd: /Users/noahgift/src/devml/notebooks from /Users/noahgift/src/sqor/sqor_ft_rest

# %%
df_author_ud = stats.author_unique_active_days(df)
df_author_ud = df_author_ud[df_author_ud["active_ratio"] <1]

# %%
df_author_ud.sort_values(by="active_ratio",ascending=False,inplace=True)
df_author_ud.head(30)
# Out:
#              author_name  active_days active_duration  active_ratio
# 256                mikev            7          8 days          0.88
# 162         Nat Williams            5          6 days          0.83
# 243              gardano           18         22 days          0.82
# 14          Andres Canal            8         10 days          0.80
# 171         Pablo Villar           21         30 days          0.70
# 238           brainTrain          216        311 days          0.69
# 197      Sebastian Blask            2          3 days          0.67
# 181        Praful Mathur            2          3 days          0.67
# 118          Jos Boumans            2          3 days          0.67
# 131            Kirk Woll          401        615 days          0.65
# 135          Laura Brown           18         28 days          0.64
# 159              Nam Kim          181        281 days          0.64
# 109         Jay Negandhi           15         25 days          0.60
# 5     Alejandro Mataloni           31         52 days          0.60
# 219    Torbjörn Norinder            3          5 days          0.60
# 134       Kyle Patterson          240        417 days          0.58
# 17           Andrew Pohl           17         30 days          0.57
# 239           braintrain           31         61 days          0.51
# 76        Flavio Granero           23         45 days          0.51
# 170          Orta Therox           55        110 days          0.50
# 157    Michelangelo Mori            2          4 days          0.50
# 196           Sean Dwyer           31         62 days          0.50
# 120         Joseph Dwyer          230        470 days          0.49
# 85         Grant Mathews          214        436 days          0.49
# 110         Jay-Negandhi           40         87 days          0.46
# 105                Jason          263        590 days          0.45
# 232                aphyr            4          9 days          0.44
# 19             Andy Pohl           15         34 days          0.44
# 7    Alexander Petrovsky            4          9 days          0.44
# 101       James Mayfield          339        767 days          0.44

# %%
df_author_ud.describe()
# Out:
#        active_days           active_duration  active_ratio
# count   131.000000                       131    131.000000
# mean     36.259542  235 days 16:29:18.778625      0.224580
# std      71.519291  331 days 01:29:50.875936      0.230879
# min       2.000000           3 days 00:00:00      0.000000
# 25%       3.000000          28 days 00:00:00      0.040000
# 50%       5.000000         102 days 00:00:00      0.120000
# 75%      28.500000         327 days 12:00:00      0.375000
# max     401.000000        2657 days 00:00:00      0.880000
